# %%
from main import main

# %%
main()
# Out:
# INFO | main | main | 2025/12/07 17:42:36 - Starting run with unique ID [train_0_0_test_0_2_extra_train_0_1_ch_list_0_spatial_car_val_True_leave_run_out_intead_of_epoch_False_seed_42]
# INFO | main | main | -- Train -- Read data
# WARNING | utils.preprocessing | read_file_and_create_mne_with_annotations | Mismatch between SRs (rounded to int) [stream nominal - 512 Hz || stream effective - 499 Hz || real effective - 499 Hz]
# INFO | utils.preprocessing | read_file_and_create_mne_with_annotations | Annotations: {'MI_BEGIN': 45, 'MI_END': 45, 'REST_BEGIN': 45, 'REST_END': 45}
# INFO | main | main | -- Test -- Read data
# WARNING | utils.preprocessing | read_file_and_create_mne_with_annotations | Mismatch between SRs (rounded to int) [stream nominal - 512 Hz || stream effective - 511 Hz || real effective - 511 Hz]
# INFO | utils.preprocessing | read_file_and_create_mne_with_annotations | Annotations: {'MI_BEGIN': 30, 'MI_END': 30, 'REST_BEGIN': 30, 'REST_END': 30}
# ...
